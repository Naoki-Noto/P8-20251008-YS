# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn import metrics

# %%
data = pd.read_csv('data/data_DFT.csv')
y = pd.DataFrame(data['Yield'], columns=['Yield'])
X = data.drop(columns=['PC_ID', 'Alc_ID', 'Yield', 'PC_SMILES', 'Alc_SMILES'])
print(X.head())
print('=======================================================================')

r2_score = []
rmse_score = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=i)
    param = {"min_samples_leaf": [2, 3, 5], "max_depth": [4, 6], "l2_regularization": [0, 0.1, 1]}
    reg = GridSearchCV(HistGradientBoostingRegressor(random_state=0, max_leaf_nodes=5, max_bins=30),
                       param_grid=param, cv=5, n_jobs=12)
    reg.fit(X_train, y_train['Yield'])
    best = reg.best_estimator_
    y_pred1 = best.predict(X_train)
    y_pred2 = best.predict(X_test)
    r2 = metrics.r2_score(y_test, y_pred2)
    rmse = metrics.root_mean_squared_error(y_test, y_pred2)
    print(f'Run{i} R2 (test): {r2:.2f}, RMSE (test): {rmse:.2f}')
    r2_score.append(r2)
    rmse_score.append(rmse)
print('==========(Result)==========')
print(f'Mean R2: {np.mean(r2_score):.3f}')
print(f'SD R2: {np.std(r2_score, ddof=1):.3f}')
print(f'Mean RMSE: {np.mean(rmse_score):.3f}')
print(f'SD RMSE: {np.std(rmse_score, ddof=1):.3f}')
# Out:
#     PC_HOMO   PC_LUMO   PC_S1  PC_T1_a  PC_%Vbur50  Alc_HOMO  Alc_LUMO  \
# 0 -9.223168 -0.588574  3.7691    2.606        40.2 -8.938541  0.123538
# 1 -9.223168 -0.588574  3.7691    2.606        40.2 -8.906977  1.054154
# 2 -9.223168 -0.588574  3.7691    2.606        40.2 -8.360308  0.548846
# 3 -9.223168 -0.588574  3.7691    2.606        40.2 -8.668336  1.062317
# 4 -9.223168 -0.588574  3.7691    2.606        40.2 -8.231872  1.047351
#
#       Alc_BDE
# 0  110.283966
# 1  110.158466
# 2  110.164741
# 3  110.089441
# 4  110.409466
# =======================================================================
# Run0 R2 (test): 0.75, RMSE (test): 13.56
# Run1 R2 (test): 0.74, RMSE (test): 10.57
# Run2 R2 (test): 0.84, RMSE (test): 7.51
# Run3 R2 (test): 0.82, RMSE (test): 11.41
# Run4 R2 (test): 0.88, RMSE (test): 8.56
# Run5 R2 (test): 0.80, RMSE (test): 9.34
# Run6 R2 (test): 0.85, RMSE (test): 7.70
# Run7 R2 (test): 0.70, RMSE (test): 11.30
# Run8 R2 (test): 0.83, RMSE (test): 9.16
# Run9 R2 (test): 0.71, RMSE (test): 10.63
# ==========(Result)==========
# Mean R2: 0.792
# SD R2: 0.061
# Mean RMSE: 9.976
# SD RMSE: 1.879

# %%
data = pd.read_csv('data/data_PC_%Vbur25.csv')
y = pd.DataFrame(data['Yield'], columns=['Yield'])
X = data.drop(columns=['PC_ID', 'Alc_ID', 'Yield', 'PC_SMILES', 'Alc_SMILES'])
print(X.head())
print('=======================================================================')

r2_score = []
rmse_score = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=i)
    param = {"min_samples_leaf": [2, 3, 5], "max_depth": [4, 6], "l2_regularization": [0, 0.1, 1]}
    reg = GridSearchCV(HistGradientBoostingRegressor(random_state=0, max_leaf_nodes=5, max_bins=30),
                       param_grid=param, cv=5, n_jobs=12)
    reg.fit(X_train, y_train['Yield'])
    best = reg.best_estimator_
    y_pred1 = best.predict(X_train)
    y_pred2 = best.predict(X_test)
    r2 = metrics.r2_score(y_test, y_pred2)
    rmse = metrics.root_mean_squared_error(y_test, y_pred2)
    print(f'Run{i} R2 (test): {r2:.2f}, RMSE (test): {rmse:.2f}')
    r2_score.append(r2)
    rmse_score.append(rmse)
print('==========(Result)==========')
print(f'Mean R2: {np.mean(r2_score):.3f}')
print(f'SD R2: {np.std(r2_score, ddof=1):.3f}')
print(f'Mean RMSE: {np.mean(rmse_score):.3f}')
print(f'SD RMSE: {np.std(rmse_score, ddof=1):.3f}')
# Out:
#     PC_HOMO   PC_LUMO   PC_S1  PC_T1_a  PC_%Vbur25  Alc_HOMO  Alc_LUMO  \
# 0 -9.223168 -0.588574  3.7691    2.606        86.1 -8.938541  0.123538
# 1 -9.223168 -0.588574  3.7691    2.606        86.1 -8.906977  1.054154
# 2 -9.223168 -0.588574  3.7691    2.606        86.1 -8.360308  0.548846
# 3 -9.223168 -0.588574  3.7691    2.606        86.1 -8.668336  1.062317
# 4 -9.223168 -0.588574  3.7691    2.606        86.1 -8.231872  1.047351
#
#       Alc_BDE
# 0  110.283966
# 1  110.158466
# 2  110.164741
# 3  110.089441
# 4  110.409466
# =======================================================================
# Run0 R2 (test): 0.65, RMSE (test): 16.06
# Run1 R2 (test): 0.76, RMSE (test): 10.26
# Run2 R2 (test): 0.80, RMSE (test): 8.39
# Run3 R2 (test): 0.80, RMSE (test): 11.81
# Run4 R2 (test): 0.88, RMSE (test): 8.32
# Run5 R2 (test): 0.84, RMSE (test): 8.30
# Run6 R2 (test): 0.80, RMSE (test): 8.87
# Run7 R2 (test): 0.69, RMSE (test): 11.52
# Run8 R2 (test): 0.78, RMSE (test): 10.48
# Run9 R2 (test): 0.79, RMSE (test): 9.17
# ==========(Result)==========
# Mean R2: 0.779
# SD R2: 0.069
# Mean RMSE: 10.317
# SD RMSE: 2.401

# %%
data = pd.read_csv('data/data_PC_%Vbur35.csv')
y = pd.DataFrame(data['Yield'], columns=['Yield'])
X = data.drop(columns=['PC_ID', 'Alc_ID', 'Yield', 'PC_SMILES', 'Alc_SMILES'])
print(X.head())
print('=======================================================================')

r2_score = []
rmse_score = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=i)
    param = {"min_samples_leaf": [2, 3, 5], "max_depth": [4, 6], "l2_regularization": [0, 0.1, 1]}
    reg = GridSearchCV(HistGradientBoostingRegressor(random_state=0, max_leaf_nodes=5, max_bins=30),
                       param_grid=param, cv=5, n_jobs=12)
    reg.fit(X_train, y_train['Yield'])
    best = reg.best_estimator_
    y_pred1 = best.predict(X_train)
    y_pred2 = best.predict(X_test)
    r2 = metrics.r2_score(y_test, y_pred2)
    rmse = metrics.root_mean_squared_error(y_test, y_pred2)
    print(f'Run{i} R2 (test): {r2:.2f}, RMSE (test): {rmse:.2f}')
    r2_score.append(r2)
    rmse_score.append(rmse)
print('==========(Result)==========')
print(f'Mean R2: {np.mean(r2_score):.3f}')
print(f'SD R2: {np.std(r2_score, ddof=1):.3f}')
print(f'Mean RMSE: {np.mean(rmse_score):.3f}')
print(f'SD RMSE: {np.std(rmse_score, ddof=1):.3f}')
# Out:
#     PC_HOMO   PC_LUMO   PC_S1  PC_T1_a  PC_%Vbur35  Alc_HOMO  Alc_LUMO  \
# 0 -9.223168 -0.588574  3.7691    2.606        61.6 -8.938541  0.123538
# 1 -9.223168 -0.588574  3.7691    2.606        61.6 -8.906977  1.054154
# 2 -9.223168 -0.588574  3.7691    2.606        61.6 -8.360308  0.548846
# 3 -9.223168 -0.588574  3.7691    2.606        61.6 -8.668336  1.062317
# 4 -9.223168 -0.588574  3.7691    2.606        61.6 -8.231872  1.047351
#
#       Alc_BDE
# 0  110.283966
# 1  110.158466
# 2  110.164741
# 3  110.089441
# 4  110.409466
# =======================================================================
# Run0 R2 (test): 0.66, RMSE (test): 15.65
# Run1 R2 (test): 0.72, RMSE (test): 11.01
# Run2 R2 (test): 0.79, RMSE (test): 8.58
# Run3 R2 (test): 0.78, RMSE (test): 12.46
# Run4 R2 (test): 0.86, RMSE (test): 9.23
# Run5 R2 (test): 0.84, RMSE (test): 8.34
# Run6 R2 (test): 0.78, RMSE (test): 9.20
# Run7 R2 (test): 0.62, RMSE (test): 12.79
# Run8 R2 (test): 0.74, RMSE (test): 11.29
# Run9 R2 (test): 0.79, RMSE (test): 9.16
# ==========(Result)==========
# Mean R2: 0.759
# SD R2: 0.075
# Mean RMSE: 10.771
# SD RMSE: 2.337

# %%
data = pd.read_csv('data/data_PC_BDE.csv')
y = pd.DataFrame(data['Yield'], columns=['Yield'])
X = data.drop(columns=['PC_ID', 'Alc_ID', 'Yield', 'PC_SMILES', 'Alc_SMILES'])
print(X.head())
print('=======================================================================')

r2_score = []
rmse_score = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=i)
    param = {"min_samples_leaf": [2, 3, 5], "max_depth": [4, 6], "l2_regularization": [0, 0.1, 1]}
    reg = GridSearchCV(HistGradientBoostingRegressor(random_state=0, max_leaf_nodes=5, max_bins=30),
                       param_grid=param, cv=5, n_jobs=12)
    reg.fit(X_train, y_train['Yield'])
    best = reg.best_estimator_
    y_pred1 = best.predict(X_train)
    y_pred2 = best.predict(X_test)
    r2 = metrics.r2_score(y_test, y_pred2)
    rmse = metrics.root_mean_squared_error(y_test, y_pred2)
    print(f'Run{i} R2 (test): {r2:.2f}, RMSE (test): {rmse:.2f}')
    r2_score.append(r2)
    rmse_score.append(rmse)
print('==========(Result)==========')
print(f'Mean R2: {np.mean(r2_score):.3f}')
print(f'SD R2: {np.std(r2_score, ddof=1):.3f}')
print(f'Mean RMSE: {np.mean(rmse_score):.3f}')
print(f'SD RMSE: {np.std(rmse_score, ddof=1):.3f}')
# Out:
#     PC_HOMO   PC_LUMO   PC_S1  PC_T1_a  PC_%Vbur50      PC_BDE  Alc_HOMO  \
# 0 -9.223168 -0.588574  3.7691    2.606        40.2  112.053516 -8.938541
# 1 -9.223168 -0.588574  3.7691    2.606        40.2  112.053516 -8.906977
# 2 -9.223168 -0.588574  3.7691    2.606        40.2  112.053516 -8.360308
# 3 -9.223168 -0.588574  3.7691    2.606        40.2  112.053516 -8.668336
# 4 -9.223168 -0.588574  3.7691    2.606        40.2  112.053516 -8.231872
#
#    Alc_LUMO     Alc_BDE
# 0  0.123538  110.283966
# 1  1.054154  110.158466
# 2  0.548846  110.164741
# 3  1.062317  110.089441
# 4  1.047351  110.409466
# =======================================================================
# Run0 R2 (test): 0.75, RMSE (test): 13.51
# Run1 R2 (test): 0.79, RMSE (test): 9.70
# Run2 R2 (test): 0.84, RMSE (test): 7.44
# Run3 R2 (test): 0.77, RMSE (test): 12.78
# Run4 R2 (test): 0.85, RMSE (test): 9.57
# Run5 R2 (test): 0.78, RMSE (test): 9.90
# Run6 R2 (test): 0.83, RMSE (test): 8.27
# Run7 R2 (test): 0.75, RMSE (test): 10.34
# Run8 R2 (test): 0.81, RMSE (test): 9.80
# Run9 R2 (test): 0.67, RMSE (test): 11.44
# ==========(Result)==========
# Mean R2: 0.782
# SD R2: 0.053
# Mean RMSE: 10.275
# SD RMSE: 1.868

# %%
data = pd.read_csv('data/data_PC_T1_v.csv')
y = pd.DataFrame(data['Yield'], columns=['Yield'])
X = data.drop(columns=['PC_ID', 'Alc_ID', 'Yield', 'PC_SMILES', 'Alc_SMILES'])
print(X.head())
print('=======================================================================')

r2_score = []
rmse_score = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=i)
    param = {"min_samples_leaf": [2, 3, 5], "max_depth": [4, 6], "l2_regularization": [0, 0.1, 1]}
    reg = GridSearchCV(HistGradientBoostingRegressor(random_state=0, max_leaf_nodes=5, max_bins=30),
                       param_grid=param, cv=5, n_jobs=12)
    reg.fit(X_train, y_train['Yield'])
    best = reg.best_estimator_
    y_pred1 = best.predict(X_train)
    y_pred2 = best.predict(X_test)
    r2 = metrics.r2_score(y_test, y_pred2)
    rmse = metrics.root_mean_squared_error(y_test, y_pred2)
    print(f'Run{i} R2 (test): {r2:.2f}, RMSE (test): {rmse:.2f}')
    r2_score.append(r2)
    rmse_score.append(rmse)
print('==========(Result)==========')
print(f'Mean R2: {np.mean(r2_score):.3f}')
print(f'SD R2: {np.std(r2_score, ddof=1):.3f}')
print(f'Mean RMSE: {np.mean(rmse_score):.3f}')
print(f'SD RMSE: {np.std(rmse_score, ddof=1):.3f}')
# Out:
#     PC_HOMO   PC_LUMO   PC_S1  PC_T1_v  PC_%Vbur50  Alc_HOMO  Alc_LUMO  \
# 0 -9.223168 -0.588574  3.7691   3.2591        40.2 -8.938541  0.123538
# 1 -9.223168 -0.588574  3.7691   3.2591        40.2 -8.906977  1.054154
# 2 -9.223168 -0.588574  3.7691   3.2591        40.2 -8.360308  0.548846
# 3 -9.223168 -0.588574  3.7691   3.2591        40.2 -8.668336  1.062317
# 4 -9.223168 -0.588574  3.7691   3.2591        40.2 -8.231872  1.047351
#
#       Alc_BDE
# 0  110.283966
# 1  110.158466
# 2  110.164741
# 3  110.089441
# 4  110.409466
# =======================================================================
# Run0 R2 (test): 0.75, RMSE (test): 13.47
# Run1 R2 (test): 0.77, RMSE (test): 10.08
# Run2 R2 (test): 0.81, RMSE (test): 8.03
# Run3 R2 (test): 0.80, RMSE (test): 12.04
# Run4 R2 (test): 0.87, RMSE (test): 8.75
# Run5 R2 (test): 0.80, RMSE (test): 9.30
# Run6 R2 (test): 0.82, RMSE (test): 8.52
# Run7 R2 (test): 0.70, RMSE (test): 11.28
# Run8 R2 (test): 0.81, RMSE (test): 9.65
# Run9 R2 (test): 0.76, RMSE (test): 9.67
# ==========(Result)==========
# Mean R2: 0.790
# SD R2: 0.046
# Mean RMSE: 10.081
# SD RMSE: 1.703

# %%
data = pd.read_csv('data/data_PC_SOMO.csv')
y = pd.DataFrame(data['Yield'], columns=['Yield'])
X = data.drop(columns=['PC_ID', 'Alc_ID', 'Yield', 'PC_SMILES', 'Alc_SMILES'])
print(X.head())
print('=======================================================================')

r2_score = []
rmse_score = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=i)
    param = {"min_samples_leaf": [2, 3, 5], "max_depth": [4, 6], "l2_regularization": [0, 0.1, 1]}
    reg = GridSearchCV(HistGradientBoostingRegressor(random_state=0, max_leaf_nodes=5, max_bins=30),
                       param_grid=param, cv=5, n_jobs=12)
    reg.fit(X_train, y_train['Yield'])
    best = reg.best_estimator_
    y_pred1 = best.predict(X_train)
    y_pred2 = best.predict(X_test)
    r2 = metrics.r2_score(y_test, y_pred2)
    rmse = metrics.root_mean_squared_error(y_test, y_pred2)
    print(f'Run{i} R2 (test): {r2:.2f}, RMSE (test): {rmse:.2f}')
    r2_score.append(r2)
    rmse_score.append(rmse)
print('==========(Result)==========')
print(f'Mean R2: {np.mean(r2_score):.3f}')
print(f'SD R2: {np.std(r2_score, ddof=1):.3f}')
print(f'Mean RMSE: {np.mean(rmse_score):.3f}')
print(f'SD RMSE: {np.std(rmse_score, ddof=1):.3f}')
# Out:
#    PC_lSOMO  PC_uSOMO   PC_S1  PC_T1_a  PC_%Vbur50  Alc_HOMO  Alc_LUMO  \
# 0 -9.298815 -6.408463  3.7691    2.606        40.2 -8.938541  0.123538
# 1 -9.298815 -6.408463  3.7691    2.606        40.2 -8.906977  1.054154
# 2 -9.298815 -6.408463  3.7691    2.606        40.2 -8.360308  0.548846
# 3 -9.298815 -6.408463  3.7691    2.606        40.2 -8.668336  1.062317
# 4 -9.298815 -6.408463  3.7691    2.606        40.2 -8.231872  1.047351
#
#       Alc_BDE
# 0  110.283966
# 1  110.158466
# 2  110.164741
# 3  110.089441
# 4  110.409466
# =======================================================================
# Run0 R2 (test): 0.77, RMSE (test): 12.91
# Run1 R2 (test): 0.76, RMSE (test): 10.22
# Run2 R2 (test): 0.86, RMSE (test): 7.02
# Run3 R2 (test): 0.81, RMSE (test): 11.54
# Run4 R2 (test): 0.83, RMSE (test): 10.14
# Run5 R2 (test): 0.69, RMSE (test): 11.67
# Run6 R2 (test): 0.59, RMSE (test): 12.76
# Run7 R2 (test): 0.56, RMSE (test): 13.76
# Run8 R2 (test): 0.75, RMSE (test): 11.16
# Run9 R2 (test): 0.73, RMSE (test): 10.31
# ==========(Result)==========
# Mean R2: 0.735
# SD R2: 0.099
# Mean RMSE: 11.149
# SD RMSE: 1.904

# %%
data = pd.read_csv('data/data_all.csv')
y = pd.DataFrame(data['Yield'], columns=['Yield'])
X = data.drop(columns=['PC_ID', 'Alc_ID', 'Yield', 'PC_SMILES', 'Alc_SMILES'])
print(X.head())
print('=======================================================================')

r2_score = []
rmse_score = []
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=i)
    param = {"min_samples_leaf": [2, 3, 5], "max_depth": [4, 6], "l2_regularization": [0, 0.1, 1]}
    reg = GridSearchCV(HistGradientBoostingRegressor(random_state=0, max_leaf_nodes=5, max_bins=30),
                       param_grid=param, cv=5, n_jobs=12)
    reg.fit(X_train, y_train['Yield'])
    best = reg.best_estimator_
    y_pred1 = best.predict(X_train)
    y_pred2 = best.predict(X_test)
    r2 = metrics.r2_score(y_test, y_pred2)
    rmse = metrics.root_mean_squared_error(y_test, y_pred2)
    print(f'Run{i} R2 (test): {r2:.2f}, RMSE (test): {rmse:.2f}')
    r2_score.append(r2)
    rmse_score.append(rmse)
print('==========(Result)==========')
print(f'Mean R2: {np.mean(r2_score):.3f}')
print(f'SD R2: {np.std(r2_score, ddof=1):.3f}')
print(f'Mean RMSE: {np.mean(rmse_score):.3f}')
print(f'SD RMSE: {np.std(rmse_score, ddof=1):.3f}')
# Out:
#     PC_HOMO   PC_LUMO  PC_lSOMO  PC_uSOMO   PC_S1  PC_T1_v  PC_%Vbur25  \
# 0 -9.223168 -0.588574 -9.298815 -6.408463  3.7691   3.2591        86.1
# 1 -9.223168 -0.588574 -9.298815 -6.408463  3.7691   3.2591        86.1
# 2 -9.223168 -0.588574 -9.298815 -6.408463  3.7691   3.2591        86.1
# 3 -9.223168 -0.588574 -9.298815 -6.408463  3.7691   3.2591        86.1
# 4 -9.223168 -0.588574 -9.298815 -6.408463  3.7691   3.2591        86.1
#
#    PC_%Vbur35  PC_%Vbur50  PC_T1_a      PC_BDE  Alc_HOMO  Alc_LUMO     Alc_BDE
# 0        61.6        40.2    2.606  112.053516 -8.938541  0.123538  110.283966
# 1        61.6        40.2    2.606  112.053516 -8.906977  1.054154  110.158466
# 2        61.6        40.2    2.606  112.053516 -8.360308  0.548846  110.164741
# 3        61.6        40.2    2.606  112.053516 -8.668336  1.062317  110.089441
# 4        61.6        40.2    2.606  112.053516 -8.231872  1.047351  110.409466
# =======================================================================
# Run0 R2 (test): 0.68, RMSE (test): 15.29
# Run1 R2 (test): 0.76, RMSE (test): 10.21
# Run2 R2 (test): 0.82, RMSE (test): 7.96
# Run3 R2 (test): 0.78, RMSE (test): 12.42
# Run4 R2 (test): 0.84, RMSE (test): 9.81
# Run5 R2 (test): 0.67, RMSE (test): 12.03
# Run6 R2 (test): 0.66, RMSE (test): 11.52
# Run7 R2 (test): 0.50, RMSE (test): 14.54
# Run8 R2 (test): 0.81, RMSE (test): 9.77
# Run9 R2 (test): 0.68, RMSE (test): 11.33
# ==========(Result)==========
# Mean R2: 0.720
# SD R2: 0.102
# Mean RMSE: 11.488
# SD RMSE: 2.232
