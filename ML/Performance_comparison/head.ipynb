# %%
import pandas as pd

# %%
data = pd.read_csv('data/data_mordred.csv')
data = data.add_prefix('mordred_')
data.to_csv('data_mordred2.csv', index=False)
data.head()
# Out:
#   mordred_PC_ID                        mordred_PC_SMILES  mordred_PC_SpAbs_A  \
# 0           PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31           22.379482
# 1           PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31           22.379482
# 2           PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31           22.379482
# 3           PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31           22.379482
# 4           PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31           22.379482
#
#    mordred_PC_SpMax_A  mordred_PC_SpDiam_A  mordred_PC_SpAD_A  \
# 0            2.554748             5.109496          22.379482
# 1            2.554748             5.109496          22.379482
# 2            2.554748             5.109496          22.379482
# 3            2.554748             5.109496          22.379482
# 4            2.554748             5.109496          22.379482
#
#    mordred_PC_SpMAD_A  mordred_PC_LogEE_A  mordred_PC_VE1_A  mordred_PC_VE2_A  \
# ...

# %%
data = pd.read_csv('data/data_RDKit.csv')
data = data.add_prefix('RDKit_')
data.to_csv('data_RDKit2.csv', index=False)
data.head()
# Out:
#   RDKit_PC_ID                          RDKit_PC_SMILES  \
# 0         PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31
# 1         PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31
# 2         PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31
# 3         PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31
# 4         PC1  O=C1C2=C(C=CC=C2)[Si](C)(C)C3=CC=CC=C31
#
#    RDKit_PC_MaxEStateIndex  RDKit_PC_MinEStateIndex  \
# 0                12.417963                -1.694437
# 1                12.417963                -1.694437
# 2                12.417963                -1.694437
# 3                12.417963                -1.694437
# 4                12.417963                -1.694437
#
#    RDKit_PC_MaxAbsEStateIndex  RDKit_PC_MinAbsEStateIndex  RDKit_PC_qed  \
# 0                   12.417963                    0.183356      0.642067
# 1                   12.417963                    0.183356      0.642067
# 2                   12.417963                    0.183356      0.642067
# ...
